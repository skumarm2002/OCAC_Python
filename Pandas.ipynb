# %%
import numpy as np

# %%
import pandas as pd

# %%
d={'a':1,'b':2,'c':3}
ser=pd.Series(data=d)
ser
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
d={'a':1,'b':2,'c':3}
ser=pd.Series(data=d,index=['a','x','c'])
ser
# Out:
# a    1.0
# x    NaN
# c    3.0
# dtype: float64

# %%
y=(['banana',16])
s=pd.Series(data=y)

# %%
s
# Out:
# 0    banana
# 1        16
# dtype: object

# %%
y=pd.Series(['banana',16],index=['name','age'])
print(y)
# Out:
# name    banana
# age         16
# dtype: object

# %%
d={'col1':[1,2,3,4],'col2':[2,3,4,5],'col3':[6,7,8,9]}
s=pd.DataFrame(data=d)
print(s)
# Out:
#    col1  col2  col3
# 0     1     2     6
# 1     2     3     7
# 2     3     4     8
# 3     4     5     9

# %%
s.shape
# Out:
# (4, 3)

# %%
s.size
# Out:
# 12

# %%
data=pd.DataFrame([[22,34,55,66],[43,56,76,88]],columns=['Pen','Mouse','Keyboard','PC'],index=['qt1','qt2'])
print(data)
# Out:
#      Pen  Mouse  Keyboard  PC
# qt1   22     34        55  66
# qt2   43     56        76  88

# %%
data.columns
# Out:
# Index(['Pen', 'Mouse', 'Keyboard', 'PC'], dtype='object')

# %%
data.keys()
# Out:
# Index(['Pen', 'Mouse', 'Keyboard', 'PC'], dtype='object')

# %%
data.keys
# Out:
# <bound method NDFrame.keys of      Pen  Mouse  Keyboard  PC
# qt1   22     34        55  66
# qt2   43     56        76  88>

# %%
data['Mobile']=[15000,2]

# %%
dr = data.drop('PC',axis=1)
dr
# Out:
#      Pen  Mouse  Keyboard  Mobile
# qt1   22     34        55   15000
# qt2   43     56        76       2

# %%
dr2=dr.drop(columns=['Mouse'])
dr2
# Out:
#      Pen  Keyboard  Mobile
# qt1   22        55   15000
# qt2   43        76       2

# %%
dr3=dr2.drop(index=['qt1'])
dr3
# Out:
#      Pen  Keyboard  Mobile
# qt2   43        76       2

# %%
data2=pd.DataFrame([[34,45,66,1330,455],[23,456,678,890,876]],columns=['Pen','Mouse','Keyboard','PC','Mobile'],index=['qt3','qt4'])
data2
# Out:
#      Pen  Mouse  Keyboard    PC  Mobile
# qt3   34     45        66  1330     455
# qt4   23    456       678   890     876

# %%
df1=pd.concat([data,data2],axis=0)
df1
# Out:
#      Pen  Mouse  Keyboard    PC  Mobile
# qt1   22     34        55    66   15000
# qt2   43     56        76    88       2
# qt3   34     45        66  1330     455
# qt4   23    456       678   890     876

# %%
#Kaggale-Data set extraction

# %%
df=pd.read_csv(r"C:\Users\Dell Pc\Downloads\archive (3)\plane_crash_info.csv")
df.head()
# Out:
#   sl no.  Fatal        Date                           Location  \
# 0      1   2907  09-11-2001     New York City, New        York
# 1      2    583  03/27/1977           Tenerife, Canary Islands
# 2      3    520  08-12-1985                 Mt. Osutaka, Japan
# 3      4    349  11-12-1996                   New Delhi, India
# 4      5    346  03-03-1974  Bois d'      Ermenonville, France
#
#                             Carrier     Flight         Type Destination
# 0  American        /United Airlines     Nov-93  B767 / B767         UAE
# 1                      Pan Am / KLM  1736/4805  B747 / B747     IRELAND
# 2                   Japan Air Lines        123         B747      MUMBAI
# 3                  Saudi / Kazastan   763/1907  B747 / Il76         NaN
# 4             Turkish      Airlines        981         DC10          UK

# %%
df=pd.read_csv("C:\\Users\\Dell Pc\\Downloads\\archive (3)\\plane_crash_info.csv")
df.head()
# Out:
#   sl no.  Fatal        Date                           Location  \
# 0      1  2907*  09-11-2001     New York City, New        York
# 1      2    583  03/27/1977           Tenerife, Canary Islands
# 2      3    520  08-12-1985                 Mt. Osutaka, Japan
# 3      4    349  11-12-1996                   New Delhi, India
# 4      5    346  03-03-1974  Bois d'      Ermenonville, France
#
#                             Carrier     Flight         Type Destination
# 0  American        /United Airlines     Nov-93  B767 / B767         UAE
# 1                      Pan Am / KLM  1736/4805  B747 / B747     IRELAND
# 2                   Japan Air Lines        123         B747      MUMBAI
# 3                  Saudi / Kazastan   763/1907  B747 / Il76         NaN
# 4             Turkish      Airlines        981         DC10          UK

# %%
df
# Out:
#     sl no.  Fatal        Date                           Location  \
# 0        1  2907*  09-11-2001     New York City, New        York
# 1        2    583  03/27/1977           Tenerife, Canary Islands
# 2        3    520  08-12-1985                 Mt. Osutaka, Japan
# 3        4    349  11-12-1996                   New Delhi, India
# 4        5    346  03-03-1974  Bois d'      Ermenonville, France
# ..     ...    ...         ...                                ...
# 99      97    133  02-04-1966                   Tokyo Bay, Japan
# 100      -    133  02-08-1993                       Tehran, Iran
# 101     99    132  03/21/2022             China Eastern Airlines
# 102    100    131  04/19/2000                    Air Philippines
# 103      -    131  11/19/1977                 TAP (Air Portugal)
#
#                               Carrier     Flight         Type Destination
# 0    American        /United Airlines     Nov-93  B767 / B767         UAE
# ...

# %%
df.tail()
# Out:
#     sl no. Fatal        Date                Location  \
# 99      97   133  02-04-1966        Tokyo Bay, Japan
# 100      -   133  02-08-1993            Tehran, Iran
# 101     99   132  03/21/2022  China Eastern Airlines
# 102    100   131  04/19/2000         Air Philippines
# 103      -   131  11/19/1977      TAP (Air Portugal)
#
#                        Carrier   Flight    Type Destination
# 99          All Nippon Airways       60    B727   SINGAPORE
# 100         Iran Air/Air Force        -  TU154M     CHENNAI
# 101     Wuzhou, Guangxi, China  MU 5735    B737       NEPAL
# 102  Samal Island, Philippines      541    B737       CHINA
# 103          Madeira, Portugal      425    B727    MALDIVES

# %%
df.head(10)
# Out:
#   sl no.  Fatal        Date                           Location  \
# 0      1  2907*  09-11-2001     New York City, New        York
# 1      2    583  03/27/1977           Tenerife, Canary Islands
# 2      3    520  08-12-1985                 Mt. Osutaka, Japan
# 3      4    349  11-12-1996                   New Delhi, India
# 4      5    346  03-03-1974  Bois d'      Ermenonville, France
# 5      6    329  06/23/1985     Atlantic Ocean West of Ireland
# 6      7    301  08/19/1980               Riyadh, Saudi Arabia
# 7      8    298  07/17/2014                   Hrabove, Ukraine
# 8      9    290  07-03-1988                       Persian Gulf
# 9     10    275  02/19/2003                      Shahdad, Iran
#
#                             Carrier     Flight         Type Destination
# 0  American        /United Airlines     Nov-93  B767 / B767         UAE
# 1                      Pan Am / KLM  1736/4805  B747 / B747     IRELAND
# ...

# %%
df.shape
# Out:
# (104, 7)

# %%
df.size
# Out:
# 728

# %%
df.describe()
# Out:
#        sl no. Fatal        Date                  Location   Carrier Flight  \
# count     103   104         104                       104       104    104
# unique     74    73         102                        97        93     90
# top         -   154  09-11-2001  Tenerife, Canary Islands  Aeroflot      -
# freq       30     4           2                         3         4     10
#
#         Type Destination
# count    104          70
# unique    45           9
# top     B727   SINGAPORE
# freq      11          13

# %%
df.describe(include='all')
# Out:
#        sl no. Fatal        Date                  Location   Carrier Flight  \
# count     103   104         104                       104       104    104
# unique     74    73         102                        97        93     90
# top         -   154  09-11-2001  Tenerife, Canary Islands  Aeroflot      -
# freq       30     4           2                         3         4     10
#
#         Type Destination
# count    104          70
# unique    45           9
# top     B727   SINGAPORE
# freq      11          13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sl no.    103 non-null    object
#  1   Fatal     104 non-null    object
#  2   Date      104 non-null    object
#  3   Location  104 non-null    object
#  4   Carrier   104 non-null    object
#  5   Flight    104 non-null    object
#  6   Type      104 non-null    object
# dtypes: object(7)
# memory usage: 5.8+ KB

# %%
df.dtypes
# Out:
# sl no.      object
# Fatal       object
# Date        object
# Location    object
# Carrier     object
# Flight      object
# Type        object
# dtype: object

# %%
df.columns
# Out:
# Index(['sl no.', 'Fatal', 'Date', 'Location', 'Carrier', 'Flight', 'Type'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sl no.       103 non-null    object
#  1   Fatal        104 non-null    object
#  2   Date         104 non-null    object
#  3   Location     104 non-null    object
#  4   Carrier      104 non-null    object
#  5   Flight       104 non-null    object
#  6   Type         104 non-null    object
#  7   Destination  70 non-null     object
# dtypes: object(8)
# memory usage: 6.6+ KB

# %%
df.isnull().sum()
# Out:
# sl no.      1
# Fatal       0
# Date        0
# Location    0
# Carrier     0
# Flight      0
# Type        0
# dtype: int64

# %%
df.describe()
# Out:
#        sl no. Fatal        Date                  Location   Carrier Flight  \
# count     103   104         104                       104       104    104
# unique     74    73         102                        97        93     90
# top         -   154  09-11-2001  Tenerife, Canary Islands  Aeroflot      -
# freq       30     4           2                         3         4     10
#
#         Type
# count    104
# unique    45
# top     B727
# freq      11

# %%
df['Fatal']
# Out:
# 0      2907*
# 1        583
# 2        520
# 3        349
# 4        346
#        ...
# 99       133
# 100      133
# 101      132
# 102      131
# 103      131
# Name: Fatal, Length: 104, dtype: object

# %%
df['Fatal'].values
# Out:
# array(['2907*', '583', '520', '349', '346', '329', '301', '298', '290',
#        '275', '273', '270', '269', '265', '264', '261', '257', '257',
#        '256', '239', '234', '230', '229', '228', '228', '227', '225',
#        '224', '223', '217', '213', '203', '200', '199', '191', '189',
#        '189', '189', '188', '183', '183', '181', '180', '178', '178',
#        '176', '176', '176', '176', '174', '171', '171', '170', '169',
#        '168', '167', '167', '166', '163', '162', '160', '160', '160',
#        '159', '159', '158', '157', '157', '156', '156', '156', '155',
#        '155', '154', '154', '154', '154', '153', '152', '152', '150',
#        '149', '148', '148', '146', '145', '144', '144', '143', '143',
#        '143', '143', '141', '141', '141', '140', '137', '135', '134',
#        '133', '133', '132', '131', '131'], dtype=object)

# %%
df["m"] = df["Fatal"]/2
df
# Out:
#     sl no.  Fatal        Date                           Location  \
# 0        1   2907  09-11-2001     New York City, New        York
# 1        2    583  03/27/1977           Tenerife, Canary Islands
# 2        3    520  08-12-1985                 Mt. Osutaka, Japan
# 3        4    349  11-12-1996                   New Delhi, India
# 4        5    346  03-03-1974  Bois d'      Ermenonville, France
# ..     ...    ...         ...                                ...
# 99      97    133  02-04-1966                   Tokyo Bay, Japan
# 100      -    133  02-08-1993                       Tehran, Iran
# 101     99    132  03/21/2022             China Eastern Airlines
# 102    100    131  04/19/2000                    Air Philippines
# 103      -    131  11/19/1977                 TAP (Air Portugal)
#
#                               Carrier     Flight         Type Destination  \
# 0    American        /United Airlines     Nov-93  B767 / B767         UAE
# ...

# %%
df.iloc[1]
# Out:
# sl no.                                2
# Fatal                               583
# Date                         03/27/1977
# Location       Tenerife, Canary Islands
# Carrier                    Pan Am / KLM
# Flight                        1736/4805
# Type                        B747 / B747
# Destination                     IRELAND
# Name: 1, dtype: object

# %%
df.iloc[5,5]
# Out:
# '182'

# %%
df.iloc[3,5]
# Out:
# '763/1907'

# %%
print(df.loc[-1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:414, in RangeIndex.get_loc(self, key)
#     413 try:
# --> 414     return self._range.index(new_key)
#     415 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 print(df.loc[-1])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
# ...

# %%
df.iloc[-1]
# Out:
# sl no.                          -
# Fatal                         131
# Date                   11/19/1977
# Location       TAP (Air Portugal)
# Carrier         Madeira, Portugal
# Flight                        425
# Type                         B727
# Destination              MALDIVES
# Name: 103, dtype: object

# %%
df.loc[1:5]
# Out:
#   sl no. Fatal        Date                           Location  \
# 1      2   583  03/27/1977           Tenerife, Canary Islands
# 2      3   520  08-12-1985                 Mt. Osutaka, Japan
# 3      4   349  11-12-1996                   New Delhi, India
# 4      5   346  03-03-1974  Bois d'      Ermenonville, France
# 5      6   329  06/23/1985     Atlantic Ocean West of Ireland
#
#                  Carrier     Flight         Type Destination       m
# 1           Pan Am / KLM  1736/4805  B747 / B747     IRELAND  583583
# 2        Japan Air Lines        123         B747      MUMBAI  520520
# 3       Saudi / Kazastan   763/1907  B747 / Il76         NaN  349349
# 4  Turkish      Airlines        981         DC10          UK  346346
# 5              Air India        182         B747          UK  329329

# %%
df.iloc[1:5]
# Out:
#   sl no. Fatal        Date                           Location  \
# 1      2   583  03/27/1977           Tenerife, Canary Islands
# 2      3   520  08-12-1985                 Mt. Osutaka, Japan
# 3      4   349  11-12-1996                   New Delhi, India
# 4      5   346  03-03-1974  Bois d'      Ermenonville, France
#
#                  Carrier     Flight         Type Destination       m
# 1           Pan Am / KLM  1736/4805  B747 / B747     IRELAND  583583
# 2        Japan Air Lines        123         B747      MUMBAI  520520
# 3       Saudi / Kazastan   763/1907  B747 / Il76         NaN  349349
# 4  Turkish      Airlines        981         DC10          UK  346346

# %%
df.set_index('Location')
df
# Out:
#     sl no.  Fatal        Date                           Location  \
# 0        1   2907  09-11-2001     New York City, New        York
# 1        2    583  03/27/1977           Tenerife, Canary Islands
# 2        3    520  08-12-1985                 Mt. Osutaka, Japan
# 3        4    349  11-12-1996                   New Delhi, India
# 4        5    346  03-03-1974  Bois d'      Ermenonville, France
# ..     ...    ...         ...                                ...
# 99      97    133  02-04-1966                   Tokyo Bay, Japan
# 100      -    133  02-08-1993                       Tehran, Iran
# 101     99    132  03/21/2022             China Eastern Airlines
# 102    100    131  04/19/2000                    Air Philippines
# 103      -    131  11/19/1977                 TAP (Air Portugal)
#
#                               Carrier     Flight         Type Destination  \
# 0    American        /United Airlines     Nov-93  B767 / B767         UAE
# ...

# %%
df.shape
# Out:
# (104, 9)

# %%
df['Location'].value_counts()
# Out:
# Location
# Tenerife, Canary Islands               3
# Madrid, Spain                          3
# Kano, Nigeria                          2
# Lagos, Nigeria                         2
# Jeddah, Saudi Arabia                   2
#                                       ..
# Off Bandra, Maharashtra, India         1
# Off Nantucket,        Massachusetts    1
# Ban Nong Rong, Thailand                1
# North Sinai, Egypt                     1
# TAP (Air Portugal)                     1
# Name: count, Length: 97, dtype: int64

# %%
df['Location'].value_counts()/len(df['Location'])*100
# Out:
# Location
# Tenerife, Canary Islands               2.884615
# Madrid, Spain                          2.884615
# Kano, Nigeria                          1.923077
# Lagos, Nigeria                         1.923077
# Jeddah, Saudi Arabia                   1.923077
#                                          ...
# Off Bandra, Maharashtra, India         0.961538
# Off Nantucket,        Massachusetts    0.961538
# Ban Nong Rong, Thailand                0.961538
# North Sinai, Egypt                     0.961538
# TAP (Air Portugal)                     0.961538
# Name: count, Length: 97, dtype: float64

# %%
df.nlargest
# Out:
# <bound method DataFrame.nlargest of     sl no.  Fatal        Date                           Location  \
# 0        1   2907  09-11-2001     New York City, New        York
# 1        2    583  03/27/1977           Tenerife, Canary Islands
# 2        3    520  08-12-1985                 Mt. Osutaka, Japan
# 3        4    349  11-12-1996                   New Delhi, India
# 4        5    346  03-03-1974  Bois d'      Ermenonville, France
# ..     ...    ...         ...                                ...
# 99      97    133  02-04-1966                   Tokyo Bay, Japan
# 100      -    133  02-08-1993                       Tehran, Iran
# 101     99    132  03/21/2022             China Eastern Airlines
# 102    100    131  04/19/2000                    Air Philippines
# 103      -    131  11/19/1977                 TAP (Air Portugal)
#
#                               Carrier     Flight         Type Destination  \
# 0    American        /United Airlines     Nov-93  B767 / B767         UAE
# ...

# %%
df['Fatal'].nsmallest
# Out:
# <bound method Series.nsmallest of 0      2907
# 1       583
# 2       520
# 3       349
# 4       346
#        ...
# 99      133
# 100     133
# 101     132
# 102     131
# 103     131
# Name: Fatal, Length: 104, dtype: int64>

# %%
df['Fatal'].nlargest
# Out:
# <bound method Series.nlargest of 0      2907
# 1       583
# 2       520
# 3       349
# 4       346
#        ...
# 99      133
# 100     133
# 101     132
# 102     131
# 103     131
# Name: Fatal, Length: 104, dtype: int64>

# %%
df.sort_values(by='Fatal',ascending=False)
# Out:
#     sl no.  Fatal        Date                           Location  \
# 0        1   2907  09-11-2001     New York City, New        York
# 1        2    583  03/27/1977           Tenerife, Canary Islands
# 2        3    520  08-12-1985                 Mt. Osutaka, Japan
# 3        4    349  11-12-1996                   New Delhi, India
# 4        5    346  03-03-1974  Bois d'      Ermenonville, France
# ..     ...    ...         ...                                ...
# 99      97    133  02-04-1966                   Tokyo Bay, Japan
# 100      -    133  02-08-1993                       Tehran, Iran
# 101     99    132  03/21/2022             China Eastern Airlines
# 102    100    131  04/19/2000                    Air Philippines
# 103      -    131  11/19/1977                 TAP (Air Portugal)
#
#                               Carrier     Flight         Type Destination  \
# 0    American        /United Airlines     Nov-93  B767 / B767         UAE
# ...

# %%
df[(df['Type']== 'B747')|(df['Type']=='B747/B747')]
# Out:
#    sl no.  Fatal        Date                        Location  \
# 2       3    520  08-12-1985              Mt. Osutaka, Japan
# 5       6    329  06/23/1985  Atlantic Ocean West of Ireland
# 11     12    270  12/21/1988             Lockerbie, Scotland
# 12     13    269  09-01-1983         Sakhalin Island, Russia
# 21     22    230  07/17/1996     Off East Moriches, New York
# 24      -    228  08-06-1997                     Agana, Guam
# 26     27    225  05/25/2002              Off Penghu, Taiwan
# 30     31    213  01-01-1978  Off Bandra, Maharashtra, India
# 41     42    181  11/27/1983                   Madrid, Spain
# 63     64    159  11/28/1987     Off Mauritius, Indian Ocean
#
#                             Carrier Flight  Type Destination      m
# 2                   Japan Air Lines    123  B747      MUMBAI  260.0
# 5                         Air India    182  B747          UK  164.5
# 11  Pan American World      Airways    103  B747         NaN  135.0
# ...
