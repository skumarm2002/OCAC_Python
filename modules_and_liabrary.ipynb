# %%
import math
math.sqrt(4)
# Out:
# 2.0

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
math.lcm(2,4)
# Out:
# 4

# %%
math.gcd(2,4)
# Out:
# 2

# %%
math.sin(30)
# Out:
# -0.9880316240928618

# %%
math.sin(45)
# Out:
# 0.8509035245341184

# %%
math.tan(45)
# Out:
# 1.6197751905438615

# %%
a=math.log(2)
print(a)
# Out:
# 0.6931471805599453

# %%
print(type(a))
# Out:
# <class 'float'>

# %%
from IPython.display import Image
Image('https://wallpapers.com/images/high/marvel-iphone-spider-man-graphic-design-3hwea6o82mluskzw.webp')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 from IPython.display import Image
# ----> 2 Image('https://wallpapers.com/images/high/marvel-iphone-spider-man-graphic-design-3hwea6o82mluskzw.webp')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\display.py:961, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     958 self.embed = embed if embed is not None else (url is None)
#     960 if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# --> 961     raise ValueError("Cannot embed the '%s' image format" % (self.format))
#     962 if self.embed:
#     963     self._mimetype = self._MIMETYPES.get(self.format)
#
# ValueError: Cannot embed the 'webp' image format

# %%
import datetime

# %%
help(datetime)
# Out:
# Help on module datetime:
#
# NAME
#     datetime - Fast implementation of the datetime type.
#
# MODULE REFERENCE
#     https://docs.python.org/3.11/library/datetime.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# CLASSES
#     builtins.object
#         date
#             datetime
#         time
#         timedelta
#         tzinfo
#             timezone
#
#     class date(builtins.object)
#      |  date(year, month, day) --> date object
#      |
#      |  Methods defined here:
#      |
#      |  __add__(self, value, /)
#      |      Return self+value.
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __format__(...)
# ...

# %%
x=datetime.datetime.now()
print(x)
# Out:
# 2024-06-28 15:53:01.041976

# %%
x=datetime.datetime(2014,8,28,9,36,58)
print(x)
# Out:
# 2014-08-28 09:36:58

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
cv2._version_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 cv2._version_
#
# AttributeError: module 'cv2' has no attribute '_version_'

# %%
import cv2
from time import sleep
key = cv2. waitKey(1)
webcam = cv2.VideoCapture(0)
sleep(2)
while True:

    try:
        check, frame = webcam.read()
        print(check) #prints true as long as the webcam is running
        print(frame) #prints matrix values of each framecd 
        cv2.imshow("Capturing", frame)
        key = cv2.waitKey(1)
        if key == ord('s'): 
            cv2.imwrite(filename='saved_img.jpg', img=frame)
            webcam.release()
            print("Processing image...")
            img_ = cv2.imread('saved_img.jpg', cv2.IMREAD_ANYCOLOR)
            print("Converting RGB image to grayscale...")
            gray = cv2.cvtColor(img_, cv2.COLOR_BGR2GRAY)
            print("Converted RGB image to grayscale...")
            print("Resizing image to 28x28 scale...")
            img_ = cv2.resize(gray,(28,28))
            print("Resized...")
            img_resized = cv2.imwrite(filename='saved_img-final.jpg', img=img_)
            print("Image saved!")
            
            break
        
        elif key == ord('q'):
            webcam.release()
            cv2.destroyAllWindows()
            break
    
    except(KeyboardInterrupt):
        print("Turning off camera.")
        webcam.release()
        print("Camera off.")
        print("Program ended.")
        cv2.destroyAllWindows()
        break
# Out:
# True
# [[[115 106 116]
#   [113 103 112]
#   [110 101 109]
#   ...
#   [ 18  41  10]
#   [ 16  39   8]
#   [ 15  37   5]]
#
#  [[109 100 110]
#   [108  99 109]
#   [106  97 106]
#   ...
#   [ 17  40   9]
#   [ 16  39   8]
#   [ 16  38   6]]
#
#  [[104  95 106]
#   [105  96 106]
#   [106  96 106]
#   ...
#   [ 15  39   9]
#   [ 16  39   9]
#   [ 16  38   7]]
#
#  ...
#
#  [[215 209 143]
#   [225 218 150]
#   [233 222 150]
#   ...
#   [  4   0   7]
#   [  4   0   7]
#   [  4   0   7]]
#
#  [[220 214 148]
#   [228 222 154]
#   [235 225 154]
#   ...
#   [  4   0   7]
#   [  4   0   7]
#   [  4   0   7]]
#
#  [[223 219 152]
#   [231 226 158]
#   [237 228 158]
#   ...
#   [  4   0   7]
#   [  4   0   7]
#   [  4   0   7]]]
# True
# [[[110  95 103]
#   [108  93 102]
#   [103  91 100]
#   ...
#   [  5  46  18]
#   [  4  44  17]
#   [  3  41  15]]
#
#  [[107  93 101]
#   [106  92 100]
#   [102  90  99]
#   ...
#   [  6  47  19]
#   [  6  45  19]
#   [  5  43  17]]
#
#  [[106  94  99]
# ...

# %%
pip install opencv-python-headless
# Out:
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB 487.6 kB/s eta 0:01:20
#    ---------------------------------------- 0.1/38.8 MB 491.5 kB/s eta 0:01:19
#    ---------------------------------------- 0.1/38.8 MB 654.9 kB/s eta 0:00:59
#    ---------------------------------------- 0.2/38.8 MB 888.4 kB/s eta 0:00:44
#    ---------------------------------------- 0.3/38.8 MB 1.0 MB/s eta 0:00:39
#    ---------------------------------------- 0.3/38.8 MB 1.0 MB/s eta 0:00:38
#    ---------------------------------------- 0.4/38.8 MB 1.0 MB/s eta 0:00:38
#    ---------------------------------------- 0.4/38.8 MB 958.4 kB/s eta 0:00:41
#    ---------------------------------------- 0.5/38.8 MB 1.0 MB/s eta 0:00:38
#    ---------------------------------------- 0.5/38.8 MB 1.0 MB/s eta 0:00:38
# ...

# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# Photo saved as 'captured_photo.jpg'
# Photo saved as 'captured_photo.jpg'
# Photo saved as 'captured_photo.jpg'
# Photo saved as 'captured_photo.jpg'
# Photo saved as 'captured_photo.jpg'
# Photo saved as 'captured_photo.jpg'

# %%
from tkinter import *
import math as m
window=Tk()
window.title("Sohan's calculator")
window.geometry("383x570+470+20")
window.config(bg="gray11")
window.resizeable(True,False)
#window.overrideredirect(1)
entry_string= StringVar()
entry=Entry(window,textvariable=entry_string,foreground="white",background="gray20")


mainloop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 7
#       5 window.geometry("383x570+470+20")
#       6 window.config(bg="gray11")
# ----> 7 window.resizeable(False,False)
#       8 #window.overrideredirect(1)
#       9 entry_string= StringVar()
#
# File ~\anaconda3\Lib\tkinter\__init__.py:2410, in Tk.__getattr__(self, attr)
#    2408 def __getattr__(self, attr):
#    2409     "Delegate attribute access to the interpreter object"
# -> 2410     return getattr(self.tk, attr)
#
# AttributeError: '_tkinter.tkapp' object has no attribute 'resizeable'

# %%
 pip install opencv-python tensorflow
